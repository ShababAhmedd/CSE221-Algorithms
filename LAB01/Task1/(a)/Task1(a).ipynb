# %%
from google.colab import drive
drive.mount("/content/drive")

input1a = open("/content/drive/MyDrive/cse221_lab/Task1/(a)/input1a.txt", "rt")
output1a = open("/content/drive/MyDrive/cse221_lab/Task1/(a)/output1a.txt", "w")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
t = input1a.readline()
#print(t)
x = int(t[0])

for lines in range(x):
  n = input1a.readline()
  strip = int(n.strip())
  if strip%2 == 0:
    output1a.write(f"{n}is an Even number \n")        #formatting prb
    print()
  else:
    output1a.write(f"{n}is an Odd number \n")
    print()

# %%
#print(input1a.read())            Why cant the files be read?
#output1a.read()
input1a.close()
output1a.close()
